# %% [markdown]
# # Development of Arctic boundary current model
#
# See `Development/TestingNavierStokes??.ipynb` series for development of NS solver in rectangular domain.
#
# 0. `ArcticBoundaryCurrentModel0.ipynb`: Adapt wind forced dishpan steady NS solver to Arctic boundary current geometry.
# 1. `ArcticBoundaryCurrentModel1.ipynb`: More work on gmsh domain.
#
# twnh July '25

# %% [markdown]
# ## Problem statement
#
# The ultimate goal is to solve a nonlinear multi-field PDE. Consider here the lid-stress-driven flow for the incompressible rotating Navier-Stokes equations. Formally, the PDE we want to solve is: find the velocity vector $u$ and the pressure anomaly $p$ such that
#
# $$
# \left\lbrace
# \begin{aligned}
# -\nu  \nabla^2 u +  (u \nabla) u + (1/\rho_0) \nabla p + f  \hat{\mathbf k} \times u = 0 &\text{ in }\Omega,\\
# \nabla\cdot u = 0 &\text{ in } \Omega,\\
# \boldsymbol{t} \cdot \boldsymbol{\sigma} \cdot \mathbf{n} = \tau_{\text{imposed}} &\text{ on } \Gamma_s, \\
# u = 0 &\text{ on } \Gamma_w,
# \end{aligned}
# \right.
# $$
#
# where the computational domain is the rectangle $\Omega \doteq (0,L_x) \times (-L_y/2,L_y/2) \times (-L_z,0)$, ${\mathbf n}$ is the unit outward normal, and $\boldsymbol{t}$ is the tangential direction at the surface, $\Gamma_s$. The driving force is the tangential stress $\tau_{\text{imposed}}$ (units of $\text{m}^{2} \text{s}^{-2}$ ). The mean value of the pressure anomaly is constrained to equal zero,
#
# $$
# \int_\Omega p \ {\rm d}\Omega = 0 .
# $$

# %%
using Gridap
using GridapSolvers
using GridapSolvers.LinearSolvers, GridapSolvers.MultilevelTools, GridapSolvers.NonlinearSolvers
using GridapSolvers.BlockSolvers: LinearSystemBlock, NonlinearSystemBlock, BiformBlock, BlockTriangularSolver
using Gridap.MultiField
using GridapGmsh
using LinearAlgebra

# %% [markdown]
# #### Define physical parameters

# %%
# Physical properties
# ν = 1e-6              # (m^2/s) kinematic viscosity
ν = 1.0e-4              # (m^2/s) kinematic viscosity
ρₒ = 1000.0             # (kg/m^3) reference density
rotation_period = 6.0   # (s) rotation rate
f = 2*2*π/rotation_period
Ekman_layer_depth = sqrt(2*ν / f) # (m), Ekman layer depth
println("Ekman layer depth: ", Ekman_layer_depth, " m")

# Surface stress boundary condition
u₁₀(y) = 1.0     # m s⁻¹, average wind velocity 10 meters above the ocean
# u₁₀(y) =  1.0 .* cos(π.*y./Ly)     # m s⁻¹, average wind velocity 10 meters above the ocean
cᴰ = 2.5e-3 # dimensionless drag coefficient
ρₐ = 1.225  # kg m⁻³, average density of air at sea-level
Qᵘ(x) = VectorValue((ρₐ / ρₒ) * cᴰ * u₁₀(x[2]) * abs(u₁₀(x[2])),0,0) # m² s⁻²
# Out:
# Ekman layer depth: 0.009772050238058399 m
# Qᵘ (generic function with 1 method)

# %% [markdown]
# Load model geometry.

# %%
model = GmshDiscreteModel("ArcticBasin1.msh")
labels = get_face_labeling(model)
label_names = model.face_labeling.tag_to_name
# Out:
# Info    : Reading 'ArcticBasin1.msh'...
# Info    : 28 entities
# Info    : 311 nodes
# Info    : 1250 elements
# Info    : Done reading 'ArcticBasin1.msh'
# Warning : Gmsh has aleady been initialized
# 5-element Vector{String}:
#  "Top"
#  "Wall"
#  "Slope"
#  "Bottom"
#  "Domain"

# %% [markdown]
# ## FE spaces
#
# See: `Development/TestingNavierStokes??.ipynb` for more info on these spaces

# %%
order = 2
qdegree = 2*(order+1)
reffeᵤ = ReferenceFE(lagrangian,VectorValue{3,Float64},order)
V = TestFESpace(model,reffeᵤ,conformity=:H1,labels=labels,dirichlet_tags=["Wall","Bottom","Slope"])
reffeₚ = ReferenceFE(lagrangian,Float64,order-1;space=:P)
Q = TestFESpace(model,reffeₚ,conformity=:L2,constraint=:zeromean)
uD0 = VectorValue(0,0,0)            # Velocity vanishes on the boundaries except the top
U = TrialFESpace(V,uD0)
P = TrialFESpace(Q)
mfs = Gridap.MultiField.BlockMultiFieldStyle()
Y = MultiFieldFESpace([V, Q];style=mfs)
X = MultiFieldFESpace([U, P];style=mfs)
# Out:
# MultiFieldFESpace()

# %% [markdown]
# ## Triangulation and integration quadrature
#
# From the discrete model we can define the triangulation and integration measure

# %%
degree = order
Ω = Triangulation(model)
dΩ = Measure(Ω,qdegree)
Γ = BoundaryTriangulation(model,tags="Top")
dΓ = Measure(Γ,degree)
# Out:
# Unknown tag name TopInner
#
#
#
# Stacktrace:
#
#   [1] error(s::String)
#
#     @ Base ./error.jl:35
#
#   [2] macro expansion
#
#     @ ~/.julia/packages/Gridap/lRBm2/src/Helpers/Macros.jl:47 [inlined]
#
#   [3] get_tag_from_name
#
#     @ ~/.julia/packages/Gridap/lRBm2/src/Geometry/FaceLabelings.jl:198 [inlined]
#
#   [4] #86
#
#     @ ~/.julia/packages/Gridap/lRBm2/src/Geometry/FaceLabelings.jl:206 [inlined]
#
#   [5] iterate
#
#     @ ./generator.jl:48 [inlined]
#
#   [6] _collect(c::Vector{String}, itr::Base.Generator{Vector{String}, Gridap.Geometry.var"#86#87"{Gridap.Geometry.FaceLabeling}}, ::Base.EltypeUnknown, isz::Base.HasShape{1})
#
#     @ Base ./array.jl:811
#
#   [7] collect_similar
#
#     @ ./array.jl:720 [inlined]
#
#   [8] map
#
#     @ ./abstractarray.jl:3371 [inlined]
#
#   [9] get_tags_from_names
#
#     @ ~/.julia/packages/Gridap/lRBm2/src/Geometry/FaceLabelings.jl:207 [inlined]
#
#  [10] _prepare_tags
#
#     @ ~/.julia/packages/Gridap/lRBm2/src/Geometry/FaceLabelings.jl:630 [inlined]
#
#  [11] get_face_mask(labeling::Gridap.Geometry.FaceLabeling, tags::String, d::Int64)
#
#     @ Gridap.Geometry ~/.julia/packages/Gridap/lRBm2/src/Geometry/FaceLabelings.jl:363
#
#  [12] #BoundaryTriangulation#197
#
#     @ ~/.julia/packages/Gridap/lRBm2/src/Geometry/BoundaryTriangulations.jl:196 [inlined]
#
#  [13] BoundaryTriangulation
#
#     @ ~/.julia/packages/Gridap/lRBm2/src/Geometry/BoundaryTriangulations.jl:190 [inlined]
#
#  [14] #BoundaryTriangulation#198
#
#     @ ~/.julia/packages/Gridap/lRBm2/src/Geometry/BoundaryTriangulations.jl:209 [inlined]
#
#  [15] top-level scope
#
#     @ ~/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/gridap/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X13sZmlsZQ==.jl:4

# %% [markdown]
# ## Steady nonlinear Navier-Stokes solver with Coriolis force.
#
# Use a preconditioned FGMRES solver. See: https://gridap.github.io/GridapSolvers.jl/stable/Examples/NavierStokes/

# %%
khat = VectorValue(0,0,1)
Coriolis(u,v,dΩ) = ∫(f * cross(khat, u) ⋅ v)dΩ # Coriolis term
b((v,q),dΓ) =  ∫(- v ⋅ Qᵘ)dΓ    # Boundary condition for the velocity

α = 1.e2    # Stabilization parameter
Π_Qh = LocalProjectionMap(divergence,Q,qdegree)
graddiv(u,v,dΩ) = ∫(α*(∇⋅v)⋅Π_Qh(u))dΩ

conv(u,∇u) = (∇u')⋅u
dconv(du,∇du,u,∇u) = conv(u,∇du)+conv(du,∇u)
c(u,v,dΩ) = ∫(v⊙(conv∘(u,∇(u))))dΩ
dc(u,du,dv,dΩ) = ∫(dv⊙(dconv∘(du,∇(du),u,∇(u))))dΩ

lap(u,v,dΩ) = ∫(ν*∇(v)⊙∇(u))dΩ

jac_u(u,du,dv,dΩ) = lap(du,dv,dΩ) + dc(u,du,dv,dΩ) + graddiv(du,dv,dΩ)
jac_u(u,du,dv,dΩ) = lap(du,dv,dΩ) + graddiv(du,dv,dΩ) + Coriolis(du,dv,dΩ)
jac((u,p),(du,dp),(dv,dq),dΩ) = jac_u(u,du,dv,dΩ) - ∫(divergence(dv)*dp)dΩ - ∫(divergence(du)*dq)dΩ

res_u(u,v,dΩ) = lap(u,v,dΩ) + c(u,v,dΩ) + graddiv(u,v,dΩ)
res_u(u,v,dΩ) = lap(u,v,dΩ) + graddiv(u,v,dΩ) + Coriolis(u,v,dΩ) 
res((u,p),(v,q),dΩ) = res_u(u,v,dΩ) - (1/ρₒ)*∫(divergence(v)*p)dΩ - (1/ρₒ)*∫(divergence(u)*q)dΩ + b((v,q),dΓ)

jac_h(x,dx,dy) = jac(x,dx,dy,dΩ)
res_h(x,dy) = res(x,dy,dΩ)
op = FEOperator(res_h,jac_h,X,Y)

solver_u = LUSolver()
solver_p = CGSolver(JacobiLinearSolver();maxiter=20,atol=1e-14,rtol=1.e-6,verbose=true)
solver_p.log.depth = 4

bblocks  = [NonlinearSystemBlock() LinearSystemBlock();
            LinearSystemBlock()    BiformBlock((p,q) -> ∫(-((ρₒ*ρₒ)/α)*p*q)dΩ,Q,Q)]
coeffs = [1.0 1.0;
          0.0 1.0]  
P = BlockTriangularSolver(bblocks,[solver_u,solver_p],coeffs,:upper)
solver = FGMRESSolver(20,P;atol=1e-11,rtol=1.e-8,verbose=true)
solver.log.depth = 2

nlsolver = NewtonSolver(solver;maxiter=20,atol=1e-10,rtol=1.e-12,verbose=true)
uh,ph = solve(nlsolver,op)
# Out:
# UndefVarError: `dΓ` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#   [1] res(::MultiFieldFEFunction{MultiFieldCellField{ReferenceDomain}}, ::MultiFieldCellField{ReferenceDomain}, dΩ::Gridap.CellData.GenericMeasure)
#
#     @ Main ~/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/gridap/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:22
#
#   [2] res_h(x::MultiFieldFEFunction{MultiFieldCellField{ReferenceDomain}}, dy::MultiFieldCellField{ReferenceDomain})
#
#     @ Main ~/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/gridap/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:25
#
#   [3] allocate_residual(op::Gridap.FESpaces.FEOperatorFromWeakForm, uh::MultiFieldFEFunction{MultiFieldCellField{ReferenceDomain}})
#
#     @ Gridap.FESpaces ~/.julia/packages/Gridap/lRBm2/src/FESpaces/FEOperatorsFromWeakForm.jl:53
#
#   [4] residual(op::Gridap.FESpaces.FEOperatorFromWeakForm, u::MultiFieldFEFunction{MultiFieldCellField{ReferenceDomain}})
#
#     @ Gridap.FESpaces ~/.julia/packages/Gridap/lRBm2/src/FESpaces/FEOperators.jl:49
#
#   [5] residual(op::Gridap.FESpaces.AlgebraicOpFromFEOp, x::BlockArrays.BlockVector{Float64, Vector{Vector{Float64}}, Tuple{BlockArrays.BlockedOneTo{Int64, Vector{Int64}}}})
#
#     @ Gridap.FESpaces ~/.julia/packages/Gridap/lRBm2/src/FESpaces/FEOperators.jl:164
#
#   [6] solve!(x::BlockArrays.BlockVector{Float64, Vector{Vector{Float64}}, Tuple{BlockArrays.BlockedOneTo{Int64, Vector{Int64}}}}, nls::NewtonSolver, op::Gridap.FESpaces.AlgebraicOpFromFEOp, cache::Nothing)
#
#     @ GridapSolvers.NonlinearSolvers ~/.julia/packages/GridapSolvers/vnmtW/src/NonlinearSolvers/NewtonRaphsonSolver.jl:32
#
#   [7] solve!(x::BlockArrays.BlockVector{Float64, Vector{Vector{Float64}}, Tuple{BlockArrays.BlockedOneTo{Int64, Vector{Int64}}}}, nls::NewtonSolver, op::Gridap.FESpaces.AlgebraicOpFromFEOp)
#
#     @ Gridap.Algebra ~/.julia/packages/Gridap/lRBm2/src/Algebra/NonlinearSolvers.jl:22
#
#   [8] solve!(u::MultiFieldFEFunction{MultiFieldCellField{ReferenceDomain}}, solver::Gridap.FESpaces.NonlinearFESolver, feop::Gridap.FESpaces.FEOperatorFromWeakForm, cache::Nothing)
#
#     @ Gridap.FESpaces ~/.julia/packages/Gridap/lRBm2/src/FESpaces/FESolvers.jl:163
#
#   [9] solve!(uh::MultiFieldFEFunction{MultiFieldCellField{ReferenceDomain}}, solver::Gridap.FESpaces.NonlinearFESolver, op::Gridap.FESpaces.FEOperatorFromWeakForm)
#
#     @ Gridap.FESpaces ~/.julia/packages/Gridap/lRBm2/src/FESpaces/FESolvers.jl:14
#
#  [10] solve(nls::Gridap.FESpaces.NonlinearFESolver, op::Gridap.FESpaces.FEOperatorFromWeakForm)
#
#     @ Gridap.FESpaces ~/.julia/packages/Gridap/lRBm2/src/FESpaces/FESolvers.jl:51
#
#  [11] solve(nls::NewtonSolver, op::Gridap.FESpaces.FEOperatorFromWeakForm)
#
#     @ Gridap.FESpaces ~/.julia/packages/Gridap/lRBm2/src/FESpaces/FESolvers.jl:56
#
#  [12] top-level scope
#
#     @ ~/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/gridap/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:41

# %% [markdown]
# Post-process and tidy up.

# %%
mag_integral = sqrt(sum( ∫( uh ⋅ uh )dΩ ))
domain_volume = sum(∫(1)dΩ)
avg_velocity_magnitude = mag_integral / domain_volume

println("Average |u| = ", avg_velocity_magnitude, " m/s. Domain volume = ", domain_volume, " m³.")

writevtk(Ω,"ArcticBoundaryCurrentModel1",cellfields=["uh"=>uh,"ph"=>ph])
# Out:
# UndefVarError: `uh` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/gridap/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X20sZmlsZQ==.jl:1
