# %% [markdown]
# # Development of Arctic boundary current model
#
# See `Development/TestingNavierStokes??.ipynb` series for development of NS solver in rectangular domain.
#
# 0. `ArcticBoundaryCurrentModel0.ipynb`: Adapt wind forced dishpan steady NS solver to Arctic boundary current geometry.
# 1. `ArcticBoundaryCurrentModel1.ipynb`: More work on gmsh domain.
# 2. `ArcticBoundaryCurrentModel2.ipynb`: More work on gmsh domain. Add cooling and freshening patches to cylinder.
# 3. `ArcticBoundaryCurrentModel3.ipynb`: More work on gmsh domain. Add warming/salinification patch. But it still errors when defining the 3D domain (it only works on the surface of the gmsh domain).
# 4.  `ArcticBoundaryCurrentModel4.ipynb`: More work on gmsh domain. Try to get cylindrical disk to work. This succeeds.
# 5.  `ArcticBoundaryCurrentModel5.ipynb`: More work on gmsh domain. Try to add cutoff cone beneath cylinder. This succeeds.
#
# twnh July '25

# %% [markdown]
# ## Problem statement
#
# The ultimate goal is to solve a nonlinear multi-field PDE. Consider here the lid-stress-driven flow for the incompressible rotating Navier-Stokes equations. Formally, the PDE we want to solve is: find the velocity vector $u$ and the pressure anomaly $p$ such that
#
# $$
# \left\lbrace
# \begin{aligned}
# -\nu  \nabla^2 u +  (u \nabla) u + (1/\rho_0) \nabla p + f  \hat{\mathbf k} \times u = 0 &\text{ in }\Omega,\\
# \nabla\cdot u = 0 &\text{ in } \Omega,\\
# \boldsymbol{t} \cdot \boldsymbol{\sigma} \cdot \mathbf{n} = \tau_{\text{imposed}} &\text{ on } \Gamma_s, \\
# u = 0 &\text{ on } \Gamma_w,
# \end{aligned}
# \right.
# $$
#
# where the computational domain is the rectangle $\Omega \doteq (0,L_x) \times (-L_y/2,L_y/2) \times (-L_z,0)$, ${\mathbf n}$ is the unit outward normal, and $\boldsymbol{t}$ is the tangential direction at the surface, $\Gamma_s$. The driving force is the tangential stress $\tau_{\text{imposed}}$ (units of $\text{m}^{2} \text{s}^{-2}$ ). The mean value of the pressure anomaly is constrained to equal zero,
#
# $$
# \int_\Omega p \ {\rm d}\Omega = 0 .
# $$

# %%
using Gridap
using GridapSolvers
using GridapSolvers.LinearSolvers, GridapSolvers.MultilevelTools, GridapSolvers.NonlinearSolvers
using GridapSolvers.BlockSolvers: LinearSystemBlock, NonlinearSystemBlock, BiformBlock, BlockTriangularSolver
using Gridap.MultiField
using GridapGmsh
using LinearAlgebra

# %% [markdown]
# #### Define physical parameters

# %%
# Physical properties
# ν = 1e-6              # (m^2/s) kinematic viscosity
ν = 1.0e-4              # (m^2/s) kinematic viscosity
ρₒ = 1000.0             # (kg/m^3) reference density
rotation_period = 6.0   # (s) rotation rate
f = 2*2*π/rotation_period
Ekman_layer_depth = sqrt(2*ν / f) # (m), Ekman layer depth
println("Ekman layer depth: ", Ekman_layer_depth, " m")

# Surface stress boundary condition
u₁₀(y) = 1.0     # m s⁻¹, average wind velocity 10 meters above the ocean
# u₁₀(y) =  1.0 .* cos(π.*y./Ly)     # m s⁻¹, average wind velocity 10 meters above the ocean
cᴰ = 2.5e-3 # dimensionless drag coefficient
ρₐ = 1.225  # kg m⁻³, average density of air at sea-level
Qᵘ(x) = VectorValue((ρₐ / ρₒ) * cᴰ * u₁₀(x[2]) * abs(u₁₀(x[2])),0,0) # m² s⁻²
# Out:
# Ekman layer depth: 0.009772050238058399 m
# Qᵘ (generic function with 1 method)

# %% [markdown]
# Load model geometry.

# %%
model = GmshDiscreteModel("ArcticBasin5.msh")
labels = get_face_labeling(model)
label_names = model.face_labeling.tag_to_name
# Out:
# Info    : Reading 'ArcticBasin5.msh'...
# Info    : 18 entities
# Info    : 1748 nodes
# Info    : 8288 elements
# Info    : Done reading 'ArcticBasin5.msh'
# 5-element Vector{String}:
#  "Top"
#  "Wall"
#  "Slope"
#  "Bottom"
#  "ArcticBasin"

# %% [markdown]
# ## FE spaces
#
# See: `Development/TestingNavierStokes??.ipynb` for more info on these spaces

# %%
order = 2
qdegree = 2*(order+1)
reffeᵤ = ReferenceFE(lagrangian,VectorValue{3,Float64},order)
V = TestFESpace(model,reffeᵤ,conformity=:H1,labels=labels,dirichlet_tags=["Wall","Bottom"])
reffeₚ = ReferenceFE(lagrangian,Float64,order-1;space=:P)
Q = TestFESpace(model,reffeₚ,conformity=:L2,constraint=:zeromean)
uD0 = VectorValue(0,0,0)            # Velocity vanishes on the boundaries except the top
U = TrialFESpace(V,uD0)
P = TrialFESpace(Q)
mfs = Gridap.MultiField.BlockMultiFieldStyle()
Y = MultiFieldFESpace([V, Q];style=mfs)
X = MultiFieldFESpace([U, P];style=mfs)
# Out:
# MultiFieldFESpace()

# %% [markdown]
# ## Triangulation and integration quadrature
#
# From the discrete model we can define the triangulation and integration measure

# %%
degree = order
Ω = Triangulation(model)
dΩ = Measure(Ω,qdegree)
Γ = BoundaryTriangulation(model,tags="Top")
dΓ = Measure(Γ,degree)
# Out:
# GenericMeasure()

# %% [markdown]
# ## Steady nonlinear Navier-Stokes solver with Coriolis force.
#
# Use a preconditioned FGMRES solver. See: https://gridap.github.io/GridapSolvers.jl/stable/Examples/NavierStokes/

# %%
khat = VectorValue(0,0,1)
Coriolis(u,v,dΩ) = ∫(f * cross(khat, u) ⋅ v)dΩ # Coriolis term
b((v,q),dΓ) =  ∫(- v ⋅ Qᵘ)dΓ    # Boundary condition for the velocity

α = 1.e2    # Stabilization parameter
Π_Qh = LocalProjectionMap(divergence,Q,qdegree)
graddiv(u,v,dΩ) = ∫(α*(∇⋅v)⋅Π_Qh(u))dΩ

conv(u,∇u) = (∇u')⋅u
dconv(du,∇du,u,∇u) = conv(u,∇du)+conv(du,∇u)
c(u,v,dΩ) = ∫(v⊙(conv∘(u,∇(u))))dΩ
dc(u,du,dv,dΩ) = ∫(dv⊙(dconv∘(du,∇(du),u,∇(u))))dΩ

lap(u,v,dΩ) = ∫(ν*∇(v)⊙∇(u))dΩ

jac_u(u,du,dv,dΩ) = lap(du,dv,dΩ) + dc(u,du,dv,dΩ) + graddiv(du,dv,dΩ)
jac_u(u,du,dv,dΩ) = lap(du,dv,dΩ) + graddiv(du,dv,dΩ) + Coriolis(du,dv,dΩ)
jac((u,p),(du,dp),(dv,dq),dΩ) = jac_u(u,du,dv,dΩ) - ∫(divergence(dv)*dp)dΩ - ∫(divergence(du)*dq)dΩ

res_u(u,v,dΩ) = lap(u,v,dΩ) + c(u,v,dΩ) + graddiv(u,v,dΩ)
res_u(u,v,dΩ) = lap(u,v,dΩ) + graddiv(u,v,dΩ) + Coriolis(u,v,dΩ) 
res((u,p),(v,q),dΩ) = res_u(u,v,dΩ) - (1/ρₒ)*∫(divergence(v)*p)dΩ - (1/ρₒ)*∫(divergence(u)*q)dΩ + b((v,q),dΓ)

jac_h(x,dx,dy) = jac(x,dx,dy,dΩ)
res_h(x,dy) = res(x,dy,dΩ)
op = FEOperator(res_h,jac_h,X,Y)

solver_u = LUSolver()
solver_p = CGSolver(JacobiLinearSolver();maxiter=20,atol=1e-14,rtol=1.e-6,verbose=true)
solver_p.log.depth = 4

bblocks  = [NonlinearSystemBlock() LinearSystemBlock();
            LinearSystemBlock()    BiformBlock((p,q) -> ∫(-((ρₒ*ρₒ)/α)*p*q)dΩ,Q,Q)]
coeffs = [1.0 1.0;
          0.0 1.0]  
P = BlockTriangularSolver(bblocks,[solver_u,solver_p],coeffs,:upper)
solver = FGMRESSolver(20,P;atol=1e-11,rtol=1.e-8,verbose=true)
solver.log.depth = 2

nlsolver = NewtonSolver(solver;maxiter=20,atol=1e-10,rtol=1.e-12,verbose=true)
uh,ph = solve(nlsolver,op)
# Out:
# --------------- Starting Newton-Raphson solver --------
#   > Iteration   0 - Residuals: 4.00e-07,   1.00e+00
#     --------------- Starting FGMRES solver ----------------
#       > Iteration   0 - Residuals: 4.00e-07,   1.00e+00
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 0.00e+00,   1.00e+00
#         Solver CG finished with reason SOLVER_CONVERGED_ATOL
#         Iterations:   0 - Residuals: 0.00e+00,   NaN
#         --------------- Exiting CG solver ---------------------
#       > Iteration   1 - Residuals: 2.05e-09,   5.11e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 8.31e-01,   8.31e-01
#           > Iteration   2 - Residuals: 4.69e-16,   4.69e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   2 - Residuals: 4.69e-16,   4.69e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration   2 - Residuals: 1.12e-09,   2.80e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.41e+00,   1.00e+00
#           > Iteration   1 - Residuals: 1.19e+00,   8.39e-01
#           > Iteration   2 - Residuals: 6.21e-16,   4.39e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   2 - Residuals: 6.21e-16,   4.39e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration   3 - Residuals: 1.12e-09,   2.80e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.02e+00,   1.00e+00
#           > Iteration   1 - Residuals: 8.39e-01,   8.18e-01
#           > Iteration   2 - Residuals: 5.86e-16,   5.72e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   2 - Residuals: 5.86e-16,   5.72e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration   4 - Residuals: 8.04e-10,   2.01e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 8.37e-01,   8.37e-01
#           > Iteration   2 - Residuals: 5.72e-16,   5.72e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   2 - Residuals: 5.72e-16,   5.72e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration   5 - Residuals: 8.04e-10,   2.01e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 8.37e-01,   8.37e-01
#           > Iteration   2 - Residuals: 4.74e-16,   4.74e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   2 - Residuals: 4.74e-16,   4.74e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration   6 - Residuals: 6.19e-10,   1.55e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 8.18e-01,   8.15e-01
#           > Iteration   2 - Residuals: 4.88e-16,   4.86e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   2 - Residuals: 4.88e-16,   4.86e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration   7 - Residuals: 5.09e-10,   1.27e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.35e+00,   1.00e+00
#           > Iteration   1 - Residuals: 1.10e+00,   8.18e-01
#           > Iteration   2 - Residuals: 6.66e-16,   4.93e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   2 - Residuals: 6.66e-16,   4.93e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration   8 - Residuals: 4.92e-10,   1.23e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.33e+00,   1.00e+00
#           > Iteration   1 - Residuals: 1.09e+00,   8.21e-01
#           > Iteration   2 - Residuals: 6.17e-16,   4.64e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   2 - Residuals: 6.17e-16,   4.64e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration   9 - Residuals: 3.98e-10,   9.96e-04
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.08e+00,   1.00e+00
#           > Iteration   1 - Residuals: 9.03e-01,   8.32e-01
#           > Iteration   2 - Residuals: 5.17e-16,   4.77e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   2 - Residuals: 5.17e-16,   4.77e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  10 - Residuals: 3.98e-10,   9.96e-04
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 8.26e-01,   8.23e-01
#           > Iteration   2 - Residuals: 4.94e-16,   4.92e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   2 - Residuals: 4.94e-16,   4.92e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration
60e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   2 - Residuals: 4.60e-16,   4.60e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  90 - Residuals: 2.80e-11,   6.99e-05
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 8.62e-01,   8.62e-01
#           > Iteration   2 - Residuals: 5.19e-16,   5.19e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   2 - Residuals: 5.19e-16,   5.19e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  91 - Residuals: 2.73e-11,   6.82e-05
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.02e+00,   1.00e+00
#           > Iteration   1 - Residuals: 8.73e-01,   8.56e-01
#           > Iteration   2 - Residuals: 4.60e-16,   4.51e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   2 - Residuals: 4.60e-16,   4.51e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  92 - Residuals: 2.67e-11,   6.67e-05
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.34e+00,   1.00e+00
#           > Iteration   1 - Residuals: 1.16e+00,   8.68e-01
#           > Iteration   2 - Residuals: 5.92e-16,   4.43e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   2 - Residuals: 5.92e-16,   4.43e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  93 - Residuals: 2.66e-11,   6.64e-05
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.35e+00,   1.00e+00
#           > Iteration   1 - Residuals: 1.15e+00,   8.52e-01
#           > Iteration   2 - Residuals: 6.03e-16,   4.46e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   2 - Residuals: 6.03e-16,   4.46e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  94 - Residuals: 2.57e-11,   6.43e-05
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.10e+00,   1.00e+00
#           > Iteration   1 - Residuals: 9.14e-01,   8.29e-01
#           > Iteration   2 - Residuals: 5.19e-16,   4.71e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   2 - Residuals: 5.19e-16,   4.71e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  95 - Residuals: 2.57e-11,   6.43e-05
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 8.33e-01,   8.31e-01
#           > Iteration   2 - Residuals: 4.72e-16,   4.71e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   2 - Residuals: 4.72e-16,   4.71e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  96 - Residuals: 2.50e-11,   6.24e-05
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 8.31e-01,   8.31e-01
#           > Iteration   2 - Residuals: 5.00e-16,   5.00e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   2 - Residuals: 5.00e-16,   5.00e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  97 - Residuals: 2.50e-11,   6.24e-05
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 8.31e-01,   8.31e-01
#           > Iteration   2 - Residuals: 4.96e-16,   4.96e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   2 - Residuals: 4.96e-16,   4.96e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  98 - Residuals: 2.44e-11,   6.10e-05
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.03e+00,   1.00e+00
#           > Iteration   1 - Residuals: 8.44e-01,   8.23e-01
#           > Iteration   2 - Residuals: 5.92e-16,   5.77e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   2 - Residuals: 5.92e-16,   5.77e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  99 - Residuals: 2.39e-11,   5.97e-05
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.40e+00,   1.00e+00
#           > Iteration   1 - Residuals: 1.15e+00,   8.26e-01
#           > Iteration   2 - Residuals: 7.06e-16,   5.06e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   2 - Residuals: 7.06e-16,   5.06e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration 100 - Residuals: 2.39e-11,   5.96e-05
#     Solver FGMRES finished with reason SOLVER_DIVERGED_MAXITER
#     Iterations: 100 - Residuals: 2.39e-11,   5.96e-05
#     --------------- Exiting FGMRES solver -----------------
#   > Iteration   1 - Residuals: 4.44e-07,   1.11e+00
#     --------------- Starting FGMRES solver ----------------
#       > Iteration   0 - Residuals: 5.56e-07,   1.00e+00
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 9.74e-01,   1.00e+00
#           > Iteration   1 - Residuals: 8.03e-01,   8.25e-01
#           > Iteration   2 - Residuals: 4.88e-16,   5.01e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   2 - Residuals: 4.88e-16,   5.01e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration   1 - Residuals: 2.05e-12,   3.68e-06
#     Solver FGMRES finished with reason SOLVER_CONVERGED_ATOL
#     Iterations:   1 - Residuals: 2.05e-12,   3.68e-06
#     --------------- Exiting FGMRES solver -----------------
#   > Iteration   2 - Residuals: 4.44e-07,   1.11e+00
#     --------------- Starting FGMRES solver ----------------
#       > Iteration   0 - Residuals: 1.05e-11,   1.00e+00
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.95e-01,   1.00e+00
#           > Iteration   1 - Residuals: 1.62e-01,   8.31e-01
#           > Iteration   2 - Residuals: 9.87e-17,   5.06e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   2 - Residuals: 9.87e-17,   5.06e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration   1 - Residuals: 2.05e-12,   1.95e-01
#     Solver FGMRES finished with reason SOLVER_CONVERGED_ATOL
#     Iterations:   1 - Residuals: 2.05e-12,   1.95e-01
#     --------------- Exiting FGMRES solver -----------------
#   > Iteration   3 - Residuals: 4.44e-07,   1.11e+00
#     --------------- Starting FGMRES solver ----------------
#       > Iteration   0 - Residuals: 2.05e-12,   1.00e+00
#     Solver FGMRES finished with reason SOLVER_CONVERGED_ATOL
#     Iterations:   0 - Residuals: 2.05e-12,   1.00e+00
#     --------------- Exiting FGMRES solver -----------------
#   > Iteration   4 - Residuals: 4.44e-07,   1.11e+00
#     --------------- Starting FGMRES solver ----------------
#       > Iteration   0 - Residuals: 2.05e-12,   1.00e+00
#     Solver FGMRES finished with reason SOLVER_CONVERGED_ATOL
#     Iterations:   0 - Residuals: 2.05e-12,   1.00e+00
#     --------------- Exiting FGMRES solver -----------------
#   > Iteration   5 - Residuals: 4.44e-07,   1.11e+00
#     --------------- Starting FGMRES solver ----------------
#       > Iteration   0 - Residuals: 2.06e-12,   1.00e+00
#     Solver FGMRES finished with reason SOLVER_CONVERGED_ATOL
#     Iterations:   0 - Residuals: 2.06e-12,   1.00e+00
#     --------------- Exiting FGMRES solver -----------------
#   > Iteration   6 - Residuals: 4.44e-07,   1.11e+00
#     --------------- Starting FGMRES solver ----------------
#       > Iteration   0 - Residuals: 2.06e-12,   1.00e+00
#     Solver FGMRES finished with reason SOLVER_CONVERGED_ATOL
#     Iterations:   0 - Residuals: 2.06e-12,   1.00e+00
#     --------------- Exiting FGMRES solver -----------------
#   > Iteration   7 - Residuals: 4.44e-07,   1.11e+00
#     --------------- Starting FGMRES solver ----------------
#       > Iteration   0 - Residuals: 2.06e-12,   1.00e+00
#     Solver FGMRES finished with reason SOLVER_CONVERGED_ATOL
#     Iterations:   0 - Residuals: 2.06e-12,   1.00e+00
#     --------------- Exiting FGMRES solver -----------------
#   > Iteration   8 - Residuals: 4.44e-07,   1.11e+00
#     --------------- Starting FGMRES solver ----------------
#       > Iteration   0 - Residuals: 2.06e-12,   1.00e+00
#     Solver FGMRES finished with reason SOLVER_CONVERGED_ATOL
#     Iterations:   0 - Residuals: 2.06e-12,   1.00e+00
#     --------------- Exiting FGMRES solver -----------------
#   > Iteration   9 - Residuals: 4.44e-07,   1.11e+00
#     --------------- Starting FGMRES solver ----------------
#       > Iteration   0 - Residuals: 2.06e-12,   1.00e+00
#     Solver FGMRES finished with reason SOLVER_CONVERGED_ATOL
#     Iterations:   0 - Residuals: 2.06e-12,   1.00e+00
#     --------------- Exiting FGMRES solver -----------------
#   > Iteration  10 - Residuals: 4.44e-07,   1.11e+00

# %% [markdown]
# Post-process and tidy up.

# %%
mag_integral = sqrt(sum( ∫( uh ⋅ uh )dΩ ))
domain_volume = sum(∫(1)dΩ)
avg_velocity_magnitude = mag_integral / domain_volume

println("Average |u| = ", avg_velocity_magnitude, " m/s. Domain volume = ", domain_volume, " m³.")

writevtk(Ω,"ArcticBoundaryCurrentModel5",cellfields=["uh"=>uh,"ph"=>ph])
