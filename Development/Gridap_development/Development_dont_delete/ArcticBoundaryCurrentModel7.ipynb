# %% [markdown]
# # Development of Arctic boundary current model
#
# See `Development/TestingNavierStokes??.ipynb` series for development of NS solver in rectangular domain.
#
# 0. `ArcticBoundaryCurrentModel0.ipynb`: Adapt wind forced dishpan steady NS solver to Arctic boundary current geometry.
# 1. `ArcticBoundaryCurrentModel1.ipynb`: More work on gmsh domain.
# 2. `ArcticBoundaryCurrentModel2.ipynb`: More work on gmsh domain. Add cooling and freshening patches to cylinder.
# 3. `ArcticBoundaryCurrentModel3.ipynb`: More work on gmsh domain. Add warming/salinification patch. But it still errors when defining the 3D domain (it only works on the surface of the gmsh domain).
# 4.  `ArcticBoundaryCurrentModel4.ipynb`: More work on gmsh domain. Try to get cylindrical disk to work. This succeeds.
# 5.  `ArcticBoundaryCurrentModel5.ipynb`: More work on gmsh domain. Try to add cutoff cone beneath cylinder. This succeeds, except the gridap solution is zero in the cone.
# 6.  `ArcticBoundaryCurrentModel6.ipynb`: More work on gmsh domain. Try to join cylinder and cone beneath cylinder. See also `GridapGmsh_demo.ipynb`. This succeeds.
# 7.  `ArcticBoundaryCurrentModel7.ipynb`: More work on gmsh domain. Try to add warming/salinification patch...this takes a long time to get the Gmsh .geo file working right. See Development/mwe_openCASCADE_{errors,works}.geo.
#
# twnh July '25

# %% [markdown]
# ## Problem statement
#
# The ultimate goal is to solve a nonlinear multi-field PDE. Consider here the lid-stress-driven flow for the incompressible rotating Navier-Stokes equations. Formally, the PDE we want to solve is: find the velocity vector $u$ and the pressure anomaly $p$ such that
#
# $$
# \left\lbrace
# \begin{aligned}
# -\nu  \nabla^2 u +  (u \nabla) u + (1/\rho_0) \nabla p + f  \hat{\mathbf k} \times u = 0 &\text{ in }\Omega,\\
# \nabla\cdot u = 0 &\text{ in } \Omega,\\
# \boldsymbol{t} \cdot \boldsymbol{\sigma} \cdot \mathbf{n} = \tau_{\text{imposed}} &\text{ on } \Gamma_s, \\
# u = 0 &\text{ on } \Gamma_w,
# \end{aligned}
# \right.
# $$
#
# where the computational domain is the rectangle $\Omega \doteq (0,L_x) \times (-L_y/2,L_y/2) \times (-L_z,0)$, ${\mathbf n}$ is the unit outward normal, and $\boldsymbol{t}$ is the tangential direction at the surface, $\Gamma_s$. The driving force is the tangential stress $\tau_{\text{imposed}}$ (units of $\text{m}^{2} \text{s}^{-2}$ ). The mean value of the pressure anomaly is constrained to equal zero,
#
# $$
# \int_\Omega p \ {\rm d}\Omega = 0 .
# $$

# %%
using Gridap
using GridapSolvers
using GridapSolvers.LinearSolvers, GridapSolvers.MultilevelTools, GridapSolvers.NonlinearSolvers
using GridapSolvers.BlockSolvers: LinearSystemBlock, NonlinearSystemBlock, BiformBlock, BlockTriangularSolver
using Gridap.MultiField
using GridapGmsh
using LinearAlgebra

# %% [markdown]
# #### Define physical parameters

# %%
# Physical properties
# ν = 1e-6              # (m^2/s) kinematic viscosity
ν = 1.0e-4              # (m^2/s) kinematic viscosity
ρₒ = 1000.0             # (kg/m^3) reference density
rotation_period = 6.0   # (s) rotation rate
f = 2*2*π/rotation_period
Ekman_layer_depth = sqrt(2*ν / f) # (m), Ekman layer depth
println("Ekman layer depth: ", Ekman_layer_depth, " m")

# Surface stress boundary condition
u₁₀(y) = 1.0     # m s⁻¹, average wind velocity 10 meters above the ocean
# u₁₀(y) =  1.0 .* cos(π.*y./Ly)     # m s⁻¹, average wind velocity 10 meters above the ocean
cᴰ = 2.5e-3 # dimensionless drag coefficient
ρₐ = 1.225  # kg m⁻³, average density of air at sea-level
Qᵘ(x) = VectorValue((ρₐ / ρₒ) * cᴰ * u₁₀(x[2]) * abs(u₁₀(x[2])),0,0) # m² s⁻²
# Out:
# Ekman layer depth: 0.009772050238058399 m
# Qᵘ (generic function with 1 method)

# %% [markdown]
# Load model geometry.

# %%
model = GmshDiscreteModel("ArcticBasin7.msh")
# writevtk(model,"model")
labels = get_face_labeling(model)
label_names = model.face_labeling.tag_to_name
# Out:
# Info    : Reading 'ArcticBasin7.msh'...
# Info    : 16 entities
# Info    : 225 nodes
# Info    : 1088 elements
# Info    : Done reading 'ArcticBasin7.msh'
# Warning : Gmsh has aleady been initialized
# 6-element Vector{String}:
#  "Wall"
#  "FresheningPatch"
#  "Slope"
#  "Bottom"
#  "CoolingPatch"
#  "ArcticBasin"

# %% [markdown]
# ## FE spaces
#
# See: `Development/TestingNavierStokes??.ipynb` for more info on these spaces

# %%
order = 2
qdegree = 2*(order+1)
reffeᵤ = ReferenceFE(lagrangian,VectorValue{3,Float64},order)
V = TestFESpace(model,reffeᵤ,conformity=:H1,labels=labels,dirichlet_tags=["Wall","Bottom","Slope"])
reffeₚ = ReferenceFE(lagrangian,Float64,order-1;space=:P)
Q = TestFESpace(model,reffeₚ,conformity=:L2,constraint=:zeromean)
uD0 = VectorValue(0,0,0)            # Velocity vanishes on the boundaries except the top
U = TrialFESpace(V,uD0)
P = TrialFESpace(Q)
mfs = Gridap.MultiField.BlockMultiFieldStyle()
Y = MultiFieldFESpace([V, Q];style=mfs)
X = MultiFieldFESpace([U, P];style=mfs)
# Out:
# MultiFieldFESpace()

# %% [markdown]
# ## Triangulation and integration quadrature
#
# From the discrete model we can define the triangulation and integration measure

# %%
degree = order
Ω = Triangulation(model)
dΩ = Measure(Ω,qdegree)
Γ = BoundaryTriangulation(model,tags="CoolingPatch")
dΓ = Measure(Γ,degree)
# Out:
# GenericMeasure()

# %% [markdown]
# ## Steady nonlinear Navier-Stokes solver with Coriolis force.
#
# Use a preconditioned FGMRES solver. See: https://gridap.github.io/GridapSolvers.jl/stable/Examples/NavierStokes/

# %%
khat = VectorValue(0,0,1)
Coriolis(u,v,dΩ) = ∫(f * cross(khat, u) ⋅ v)dΩ # Coriolis term
b((v,q),dΓ) =  ∫(- v ⋅ Qᵘ)dΓ    # Boundary condition for the velocity

α = 1.e2    # Stabilization parameter
Π_Qh = LocalProjectionMap(divergence,Q,qdegree)
graddiv(u,v,dΩ) = ∫(α*(∇⋅v)⋅Π_Qh(u))dΩ

conv(u,∇u) = (∇u')⋅u
dconv(du,∇du,u,∇u) = conv(u,∇du)+conv(du,∇u)
c(u,v,dΩ) = ∫(v⊙(conv∘(u,∇(u))))dΩ
dc(u,du,dv,dΩ) = ∫(dv⊙(dconv∘(du,∇(du),u,∇(u))))dΩ

lap(u,v,dΩ) = ∫(ν*∇(v)⊙∇(u))dΩ

jac_u(u,du,dv,dΩ) = lap(du,dv,dΩ) + dc(u,du,dv,dΩ) + graddiv(du,dv,dΩ)
jac_u(u,du,dv,dΩ) = lap(du,dv,dΩ) + graddiv(du,dv,dΩ) + Coriolis(du,dv,dΩ)
jac((u,p),(du,dp),(dv,dq),dΩ) = jac_u(u,du,dv,dΩ) - ∫(divergence(dv)*dp)dΩ - ∫(divergence(du)*dq)dΩ

res_u(u,v,dΩ) = lap(u,v,dΩ) + c(u,v,dΩ) + graddiv(u,v,dΩ)
res_u(u,v,dΩ) = lap(u,v,dΩ) + graddiv(u,v,dΩ) + Coriolis(u,v,dΩ) 
res((u,p),(v,q),dΩ) = res_u(u,v,dΩ) - (1/ρₒ)*∫(divergence(v)*p)dΩ - (1/ρₒ)*∫(divergence(u)*q)dΩ + b((v,q),dΓ)

jac_h(x,dx,dy) = jac(x,dx,dy,dΩ)
res_h(x,dy) = res(x,dy,dΩ)
op = FEOperator(res_h,jac_h,X,Y)

solver_u = LUSolver()
solver_p = CGSolver(JacobiLinearSolver();maxiter=20,atol=1e-14,rtol=1.e-6,verbose=true)
solver_p.log.depth = 4

bblocks  = [NonlinearSystemBlock() LinearSystemBlock();
            LinearSystemBlock()    BiformBlock((p,q) -> ∫(-((ρₒ*ρₒ)/α)*p*q)dΩ,Q,Q)]
coeffs = [1.0 1.0;
          0.0 1.0]  
P = BlockTriangularSolver(bblocks,[solver_u,solver_p],coeffs,:upper)
solver = FGMRESSolver(20,P;atol=1e-11,rtol=1.e-8,verbose=true)
solver.log.depth = 2

nlsolver = NewtonSolver(solver;maxiter=20,atol=1e-10,rtol=1.e-12,verbose=true)
uh,ph = solve(nlsolver,op)
# Out:
# --------------- Starting Newton-Raphson solver --------
#   > Iteration   0 - Residuals: 4.18e-07,   1.00e+00
#     --------------- Starting FGMRES solver ----------------
#       > Iteration   0 - Residuals: 4.18e-07,   1.00e+00
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 0.00e+00,   1.00e+00
#         Solver CG finished with reason SOLVER_CONVERGED_ATOL
#         Iterations:   0 - Residuals: 0.00e+00,   NaN
#         --------------- Exiting CG solver ---------------------
#       > Iteration   1 - Residuals: 6.75e-09,   1.61e-02
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.16e-01,   7.16e-01
#           > Iteration   2 - Residuals: 6.38e-03,   6.38e-03
#           > Iteration   3 - Residuals: 2.65e-16,   2.65e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.65e-16,   2.65e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration   2 - Residuals: 4.39e-09,   1.05e-02
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.41e+00,   1.00e+00
#           > Iteration   1 - Residuals: 1.02e+00,   7.22e-01
#           > Iteration   2 - Residuals: 6.76e-03,   4.78e-03
#           > Iteration   3 - Residuals: 4.19e-16,   2.96e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 4.19e-16,   2.96e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration   3 - Residuals: 4.39e-09,   1.05e-02
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.53e-01,   7.52e-01
#           > Iteration   2 - Residuals: 4.73e-04,   4.72e-04
#           > Iteration   3 - Residuals: 3.19e-16,   3.19e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 3.19e-16,   3.19e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration   4 - Residuals: 3.50e-09,   8.35e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.47e-01,   7.47e-01
#           > Iteration   2 - Residuals: 7.11e-03,   7.11e-03
#           > Iteration   3 - Residuals: 3.36e-16,   3.36e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 3.36e-16,   3.36e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration   5 - Residuals: 2.87e-09,   6.85e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.41e+00,   1.00e+00
#           > Iteration   1 - Residuals: 1.05e+00,   7.40e-01
#           > Iteration   2 - Residuals: 7.67e-03,   5.42e-03
#           > Iteration   3 - Residuals: 4.67e-16,   3.30e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 4.67e-16,   3.30e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration   6 - Residuals: 2.87e-09,   6.85e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.04e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.82e-01,   7.50e-01
#           > Iteration   2 - Residuals: 5.14e-04,   4.93e-04
#           > Iteration   3 - Residuals: 2.95e-16,   2.83e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.95e-16,   2.83e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration   7 - Residuals: 2.40e-09,   5.73e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 9.99e-01,   1.00e+00
#           > Iteration   1 - Residuals: 7.20e-01,   7.20e-01
#           > Iteration   2 - Residuals: 2.89e-03,   2.89e-03
#           > Iteration   3 - Residuals: 2.65e-16,   2.65e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.65e-16,   2.65e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration   8 - Residuals: 2.31e-09,   5.51e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.12e+00,   1.00e+00
#           > Iteration   1 - Residuals: 8.08e-01,   7.20e-01
#           > Iteration   2 - Residuals: 4.31e-03,   3.84e-03
#           > Iteration   3 - Residuals: 3.12e-16,   2.78e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 3.12e-16,   2.78e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration   9 - Residuals: 2.10e-09,   5.01e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.37e+00,   1.00e+00
#           > Iteration   1 - Residuals: 1.02e+00,   7.47e-01
#           > Iteration   2 - Residuals: 3.29e-03,   2.40e-03
#           > Iteration   3 - Residuals: 5.41e-16,   3.95e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 5.41e-16,   3.95e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  10 - Residuals: 1.91e-09,   4.56e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.32e+00,   1.00e+00
#           > Iteration   1 - Residuals: 9.76e-01,   7.40e-01
#           > Iteration   2 - Residuals: 9.28e-03,   7.04e-03
#           > Iteration   3 - Residuals: 3.78e-16,   2.87e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 3.78e-16,   2.87e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  11 - Residuals: 1.91e-09,   4.56e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.69e-01,   7.68e-01
#           > Iteration   2 - Residuals: 7.43e-03,   7.43e-03
#           > Iteration   3 - Residuals: 2.73e-16,   2.73e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.73e-16,   2.73e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  12 - Residuals: 1.74e-09,   4.16e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.02e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.74e-01,   7.61e-01
#           > Iteration   2 - Residuals: 2.93e-03,   2.88e-03
#           > Iteration   3 - Residuals: 2.92e-16,   2.87e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.92e-16,   2.87e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  13 - Residuals: 1.63e-09,   3.89e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.41e+00,   1.00e+00
#           > Iteration   1 - Residuals: 1.03e+00,   7.30e-01
#           > Iteration   2 - Residuals: 1.81e-02,   1.28e-02
#           > Iteration   3 - Residuals: 4.23e-16,   2.99e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 4.23e-16,   2.99e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  14 - Residuals: 1.63e-09,   3.89e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.25e-01,   7.24e-01
#           > Iteration   2 - Residuals: 1.53e-02,   1.53e-02
#           > Iteration   3 - Residuals: 2.85e-16,   2.85e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.85e-16,   2.85e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  15 - Residuals: 1.57e-09,   3.76e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.11e-01,   7.11e-01
#           > Iteration   2 - Residuals: 1.51e-04,   1.51e-04
#           > Iteration   3 - Residuals: 2.75e-16,   2.75e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.75e-16,   2.75e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  16 - Residuals: 1.51e-09,   3.61e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.41e+00,   1.00e+00
#           > Iteration   1 - Residuals: 9.95e-01,   7.04e-01
#           > Iteration   2 - Residuals: 3.65e-03,   2.59e-03
#           > Iteration   3 - Residuals: 4.43e-16,   3.13e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 4.43e-16,   3.13e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  17 - Residuals: 1.51e-09,   3.61e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.06e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.74e-01,   7.31e-01
#           > Iteration   2 - Residuals: 3.56e-03,   3.36e-03
#           > Iteration   3 - Residuals: 3.29e-16,   3.10e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 3.29e-16,   3.10e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  18 - Residuals: 1.45e-09,   3.46e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.11e-01,   7.10e-01
#           > Iteration   2 - Residuals: 1.23e-03,   1.23e-03
#           > Iteration   3 - Residuals: 2.82e-16,   2.81e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.82e-16,   2.81e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  19 - Residuals: 1.44e-09,   3.45e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.05e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.37e-01,   7.04e-01
#           > Iteration   2 - Residuals: 3.06e-03,   2.92e-03
#           > Iteration   3 - Residuals: 2.89e-16,   2.76e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.89e-16,   2.76e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  20 - Residuals: 1.39e-09,   3.33e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.26e+00,   1.00e+00
#           > Iteration   1 - Residuals: 9.45e-01,   7.50e-01
#           > Iteration   2 - Residuals: 7.16e-03,   5.69e-03
#           > Iteration   3 - Residuals: 3.43e-16,   2.72e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 3.43e-16,   2.72e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  21 - Residuals: 1.34e-09,   3.21e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.38e+00,   1.00e+00
#           > Iteration   1 - Residuals: 1.06e+00,   7.69e-01
#           > Iteration   2 - Residuals: 7.12e-03,   5.16e-03
#           > Iteration   3 - Residuals: 4.03e-16,   2.92e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 4.03e-16,   2.92e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  22 - Residuals: 1.34e-09,   3.21e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.57e-01,   7.57e-01
#           > Iteration   2 - Residuals: 1.66e-03,   1.66e-03
#           > Iteration   3 - Residuals: 2.61e-16,   2.61e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.61e-16,   2.61e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  23 - Residuals: 1.29e-09,   3.09e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.01e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.12e-01,   7.08e-01
#           > Iteration   2 - Residuals: 5.17e-03,   5.14e-03
#           > Iteration   3 - Residuals: 2.99e-16,   2.97e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.99e-16,   2.97e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  24 - Residuals: 1.25e-09,   3.00e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.41e+00,   1.00e+00
#           > Iteration   1 - Residuals: 1.04e+00,   7.32e-01
#           > Iteration   2 - Residuals: 1.97e-03,   1.39e-03
#           > Iteration   3 - Residuals: 4.19e-16,   2.96e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 4.19e-16,   2.96e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  25 - Residuals: 1.25e-09,   3.00e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.69e-01,   7.66e-01
#           > Iteration   2 - Residuals: 7.17e-03,   7.15e-03
#           > Iteration   3 - Residuals: 2.87e-16,   2.86e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.87e-16,   2.86e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  26 - Residuals: 1.22e-09,   2.91e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.47e-01,   7.46e-01
#           > Iteration   2 - Residuals: 1.84e-03,   1.83e-03
#           > Iteration   3 - Residuals: 3.07e-16,   3.06e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 3.07e-16,   3.06e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  27 - Residuals: 1.18e-09,   2.83e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.40e+00,   1.00e+00
#           > Iteration   1 - Residuals: 1.03e+00,   7.39e-01
#           > Iteration   2 - Residuals: 1.96e-03,   1.40e-03
#           > Iteration   3 - Residuals: 3.80e-16,   2.71e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 3.80e-16,   2.71e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  28 - Residuals: 1.18e-09,   2.82e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.17e+00,   1.00e+00
#           > Iteration   1 - Residuals: 8.84e-01,   7.52e-01
#           > Iteration   2 - Residuals: 4.47e-03,   3.80e-03
#           > Iteration   3 - Residuals: 6.89e-16,   5.86e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 6.89e-16,   5.86e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  29 - Residuals: 1.15e-09,   2.74e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.02e+00,   1.00e+00
#           > Iteration   1 - Residuals: 6.92e-01,   6.79e-01
#           > Iteration   2 - Residuals: 9.40e-03,   9.23e-03
#           > Iteration   3 - Residuals: 2.67e-16,   2.62e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.67e-16,   2.62e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  30 - Residuals: 1.15e-09,   2.74e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.01e+00,   1.00e+00
#           > Iteration   1 - Residuals: 6.90e-01,   6.85e-01
#           > Iteration   2 - Residuals: 9.74e-03,   9.67e-03
#           > Iteration   3 - Residuals: 2.55e-16,   2.53e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.55e-16,   2.53e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  31 - Residuals: 1.12e-09,   2.67e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.11e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.97e-01,   7.18e-01
#           > Iteration   2 - Residuals: 6.21e-03,   5.59e-03
#           > Iteration   3 - Residuals: 2.81e-16,   2.53e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.81e-16,   2.53e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  32 - Residuals: 1.09e-09,   2.62e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.41e+00,   1.00e+00
#           > Iteration   1 - Residuals: 1.02e+00,   7.25e-01
#           > Iteration   2 - Residuals: 1.22e-03,   8.63e-04
#           > Iteration   3 - Residuals: 4.28e-16,   3.04e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 4.28e-16,   3.04e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  33 - Residuals: 1.09e-09,   2.62e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.31e-01,   7.30e-01
#           > Iteration   2 - Residuals: 7.19e-03,   7.19e-03
#           > Iteration   3 - Residuals: 2.69e-16,   2.69e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.69e-16,   2.69e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  34 - Residuals: 1.08e-09,   2.58e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.14e-01,   7.12e-01
#           > Iteration   2 - Residuals: 1.63e-03,   1.63e-03
#           > Iteration   3 - Residuals: 2.63e-16,   2.62e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.63e-16,   2.62e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  35 - Residuals: 1.06e-09,   2.53e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.41e+00,   1.00e+00
#           > Iteration   1 - Residuals: 1.01e+00,   7.12e-01
#           > Iteration   2 - Residuals: 2.02e-03,   1.43e-03
#           > Iteration   3 - Residuals: 4.02e-16,   2.84e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 4.02e-16,   2.84e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  36 - Residuals: 1.06e-09,   2.53e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.02e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.56e-01,   7.38e-01
#           > Iteration   2 - Residuals: 3.84e-03,   3.75e-03
#           > Iteration   3 - Residuals: 2.55e-16,   2.49e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.55e-16,   2.49e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  37 - Residuals: 1.02e-09,   2.45e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.77e-01,   7.75e-01
#           > Iteration   2 - Residuals: 1.61e-02,   1.61e-02
#           > Iteration   3 - Residuals: 2.69e-16,   2.69e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.69e-16,   2.69e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  38 - Residuals: 1.02e-09,   2.44e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.08e+00,   1.00e+00
#           > Iteration   1 - Residuals: 8.26e-01,   7.63e-01
#           > Iteration   2 - Residuals: 1.59e-02,   1.47e-02
#           > Iteration   3 - Residuals: 2.94e-16,   2.71e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.94e-16,   2.71e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  39 - Residuals: 1.00e-09,   2.40e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.33e+00,   1.00e+00
#           > Iteration   1 - Residuals: 9.69e-01,   7.31e-01
#           > Iteration   2 - Residuals: 3.28e-05,   2.48e-05
#           > Iteration   3 - Residuals: 3.89e-16,   2.94e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 3.89e-16,   2.94e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  40 - Residuals: 9.93e-10,   2.37e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.35e+00,   1.00e+00
#           > Iteration   1 - Residuals: 9.99e-01,   7.39e-01
#           > Iteration   2 - Residuals: 8.17e-03,   6.04e-03
#           > Iteration   3 - Residuals: 5.41e-16,   4.00e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 5.41e-16,   4.00e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  41 - Residuals: 9.93e-10,   2.37e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.58e-01,   7.58e-01
#           > Iteration   2 - Residuals: 8.29e-03,   8.29e-03
#           > Iteration   3 - Residuals: 4.17e-16,   4.17e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 4.17e-16,   4.17e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  42 - Residuals: 9.85e-10,   2.35e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.59e-01,   7.56e-01
#           > Iteration   2 - Residuals: 3.38e-03,   3.37e-03
#           > Iteration   3 - Residuals: 3.59e-16,   3.58e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 3.59e-16,   3.58e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  43 - Residuals: 9.74e-10,   2.33e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.41e+00,   1.00e+00
#           > Iteration   1 - Residuals: 1.06e+00,   7.51e-01
#           > Iteration   2 - Residuals: 1.39e-03,   9.81e-04
#           > Iteration   3 - Residuals: 5.28e-16,   3.74e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 5.28e-16,   3.74e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  44 - Residuals: 9.74e-10,   2.33e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.01e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.65e-01,   7.61e-01
#           > Iteration   2 - Residuals: 2.12e-03,   2.10e-03
#           > Iteration   3 - Residuals: 4.34e-16,   4.31e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 4.34e-16,   4.31e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  45 - Residuals: 9.50e-10,   2.27e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 9.99e-01,   1.00e+00
#           > Iteration   1 - Residuals: 7.08e-01,   7.08e-01
#           > Iteration   2 - Residuals: 9.62e-03,   9.63e-03
#           > Iteration   3 - Residuals: 2.60e-16,   2.60e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.60e-16,   2.60e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  46 - Residuals: 9.31e-10,   2.22e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.39e+00,   1.00e+00
#           > Iteration   1 - Residuals: 1.01e+00,   7.23e-01
#           > Iteration   2 - Residuals: 1.31e-02,   9.38e-03
#           > Iteration   3 - Residuals: 4.76e-16,   3.42e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 4.76e-16,   3.42e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  47 - Residuals: 9.30e-10,   2.22e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.22e+00,   1.00e+00
#           > Iteration   1 - Residuals: 9.42e-01,   7.71e-01
#           > Iteration   2 - Residuals: 4.31e-03,   3.53e-03
#           > Iteration   3 - Residuals: 3.29e-16,   2.70e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 3.29e-16,   2.70e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  48 - Residuals: 9.08e-10,   2.17e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.03e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.78e-01,   7.53e-01
#           > Iteration   2 - Residuals: 3.89e-03,   3.77e-03
#           > Iteration   3 - Residuals: 2.77e-16,   2.68e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.77e-16,   2.68e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  49 - Residuals: 9.08e-10,   2.17e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.01e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.61e-01,   7.57e-01
#           > Iteration   2 - Residuals: 3.06e-03,   3.04e-03
#           > Iteration   3 - Residuals: 2.74e-16,   2.72e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.74e-16,   2.72e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  50 - Residuals: 8.94e-10,   2.14e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.10e+00,   1.00e+00
#           > Iteration   1 - Residuals: 8.55e-01,   7.78e-01
#           > Iteration   2 - Residuals: 1.31e-03,   1.19e-03
#           > Iteration   3 - Residuals: 3.14e-16,   2.86e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 3.14e-16,   2.86e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  51 - Residuals: 8.80e-10,   2.10e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.41e+00,   1.00e+00
#           > Iteration   1 - Residuals: 1.09e+00,   7.72e-01
#           > Iteration   2 - Residuals: 3.71e-03,   2.63e-03
#           > Iteration   3 - Residuals: 3.95e-16,   2.80e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 3.95e-16,   2.80e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  52 - Residuals: 8.80e-10,   2.10e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.48e-01,   7.47e-01
#           > Iteration   2 - Residuals: 4.98e-03,   4.98e-03
#           > Iteration   3 - Residuals: 2.55e-16,   2.55e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.55e-16,   2.55e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  53 - Residuals: 8.67e-10,   2.07e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.31e-01,   7.28e-01
#           > Iteration   2 - Residuals: 2.50e-03,   2.49e-03
#           > Iteration   3 - Residuals: 2.58e-16,   2.57e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.58e-16,   2.57e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  54 - Residuals: 8.55e-10,   2.04e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.41e+00,   1.00e+00
#           > Iteration   1 - Residuals: 1.03e+00,   7.26e-01
#           > Iteration   2 - Residuals: 1.12e-02,   7.93e-03
#           > Iteration   3 - Residuals: 3.68e-16,   2.60e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 3.68e-16,   2.60e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  55 - Residuals: 8.55e-10,   2.04e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.01e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.43e-01,   7.38e-01
#           > Iteration   2 - Residuals: 8.73e-03,   8.67e-03
#           > Iteration   3 - Residuals: 2.91e-16,   2.89e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.91e-16,   2.89e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  56 - Residuals: 8.32e-10,   1.99e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.58e-01,   7.57e-01
#           > Iteration   2 - Residuals: 7.92e-03,   7.91e-03
#           > Iteration   3 - Residuals: 2.98e-16,   2.97e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.98e-16,   2.97e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  57 - Residuals: 8.16e-10,   1.95e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.36e+00,   1.00e+00
#           > Iteration   1 - Residuals: 1.06e+00,   7.77e-01
#           > Iteration   2 - Residuals: 4.55e-03,   3.33e-03
#           > Iteration   3 - Residuals: 4.08e-16,   2.99e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 4.08e-16,   2.99e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  58 - Residuals: 8.14e-10,   1.95e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.30e+00,   1.00e+00
#           > Iteration   1 - Residuals: 1.03e+00,   7.90e-01
#           > Iteration   2 - Residuals: 4.85e-03,   3.73e-03
#           > Iteration   3 - Residuals: 4.08e-16,   3.14e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 4.08e-16,   3.14e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  59 - Residuals: 8.06e-10,   1.93e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.06e+00,   1.00e+00
#           > Iteration   1 - Residuals: 8.08e-01,   7.59e-01
#           > Iteration   2 - Residuals: 3.27e-03,   3.08e-03
#           > Iteration   3 - Residuals: 3.12e-16,   2.93e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 3.12e-16,   2.93e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  60 - Residuals: 8.06e-10,   1.93e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.57e-01,   7.56e-01
#           > Iteration   2 - Residuals: 4.05e-03,   4.04e-03
#           > Iteration   3 - Residuals: 2.74e-16,   2.74e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.74e-16,   2.74e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  61 - Residuals: 7.96e-10,   1.90e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.06e+00,   1.00e+00
#           > Iteration   1 - Residuals: 8.31e-01,   7.87e-01
#           > Iteration   2 - Residuals: 8.75e-03,   8.29e-03
#           > Iteration   3 - Residuals: 2.92e-16,   2.77e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.92e-16,   2.77e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  62 - Residuals: 7.90e-10,   1.89e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.41e+00,   1.00e+00
#           > Iteration   1 - Residuals: 1.07e+00,   7.54e-01
#           > Iteration   2 - Residuals: 7.07e-03,   5.00e-03
#           > Iteration   3 - Residuals: 6.27e-16,   4.44e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 6.27e-16,   4.44e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  63 - Residuals: 7.90e-10,   1.89e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.59e-01,   7.58e-01
#           > Iteration   2 - Residuals: 7.23e-04,   7.22e-04
#           > Iteration   3 - Residuals: 2.65e-16,   2.65e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.65e-16,   2.65e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  64 - Residuals: 7.78e-10,   1.86e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.30e-01,   7.27e-01
#           > Iteration   2 - Residuals: 2.39e-04,   2.38e-04
#           > Iteration   3 - Residuals: 2.79e-16,   2.78e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.79e-16,   2.78e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  65 - Residuals: 7.64e-10,   1.82e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.41e+00,   1.00e+00
#           > Iteration   1 - Residuals: 1.00e+00,   7.10e-01
#           > Iteration   2 - Residuals: 2.44e-03,   1.73e-03
#           > Iteration   3 - Residuals: 4.16e-16,   2.94e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 4.16e-16,   2.94e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  66 - Residuals: 7.64e-10,   1.82e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.07e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.90e-01,   7.40e-01
#           > Iteration   2 - Residuals: 2.15e-03,   2.01e-03
#           > Iteration   3 - Residuals: 2.79e-16,   2.61e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.79e-16,   2.61e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  67 - Residuals: 7.53e-10,   1.80e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.31e-01,   7.29e-01
#           > Iteration   2 - Residuals: 8.47e-03,   8.44e-03
#           > Iteration   3 - Residuals: 3.08e-16,   3.07e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 3.08e-16,   3.07e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  68 - Residuals: 7.53e-10,   1.80e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.03e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.52e-01,   7.31e-01
#           > Iteration   2 - Residuals: 1.10e-02,   1.07e-02
#           > Iteration   3 - Residuals: 2.60e-16,   2.53e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.60e-16,   2.53e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  69 - Residuals: 7.46e-10,   1.78e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.21e+00,   1.00e+00
#           > Iteration   1 - Residuals: 8.76e-01,   7.23e-01
#           > Iteration   2 - Residuals: 1.43e-02,   1.18e-02
#           > Iteration   3 - Residuals: 3.86e-16,   3.19e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 3.86e-16,   3.19e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  70 - Residuals: 7.37e-10,   1.76e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.39e+00,   1.00e+00
#           > Iteration   1 - Residuals: 9.48e-01,   6.80e-01
#           > Iteration   2 - Residuals: 6.12e-03,   4.39e-03
#           > Iteration   3 - Residuals: 3.86e-16,   2.77e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 3.86e-16,   2.77e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  71 - Residuals: 7.37e-10,   1.76e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.11e-01,   7.11e-01
#           > Iteration   2 - Residuals: 5.44e-03,   5.44e-03
#           > Iteration   3 - Residuals: 2.74e-16,   2.74e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.74e-16,   2.74e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  72 - Residuals: 7.29e-10,   1.74e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 6.82e-01,   6.81e-01
#           > Iteration   2 - Residuals: 1.90e-03,   1.89e-03
#           > Iteration   3 - Residuals: 4.40e-16,   4.39e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 4.40e-16,   4.39e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  73 - Residuals: 7.17e-10,   1.71e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.41e+00,   1.00e+00
#           > Iteration   1 - Residuals: 9.80e-01,   6.93e-01
#           > Iteration   2 - Residuals: 1.30e-02,   9.21e-03
#           > Iteration   3 - Residuals: 3.67e-16,   2.59e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 3.67e-16,   2.59e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  74 - Residuals: 7.17e-10,   1.71e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.01e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.45e-01,   7.41e-01
#           > Iteration   2 - Residuals: 1.15e-02,   1.14e-02
#           > Iteration   3 - Residuals: 2.88e-16,   2.86e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.88e-16,   2.86e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  75 - Residuals: 7.11e-10,   1.70e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.44e-01,   7.43e-01
#           > Iteration   2 - Residuals: 6.13e-03,   6.11e-03
#           > Iteration   3 - Residuals: 2.68e-16,   2.67e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.68e-16,   2.67e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  76 - Residuals: 7.03e-10,   1.68e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.40e+00,   1.00e+00
#           > Iteration   1 - Residuals: 1.05e+00,   7.52e-01
#           > Iteration   2 - Residuals: 3.24e-03,   2.31e-03
#           > Iteration   3 - Residuals: 3.77e-16,   2.70e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 3.77e-16,   2.70e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  77 - Residuals: 7.02e-10,   1.68e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.18e+00,   1.00e+00
#           > Iteration   1 - Residuals: 8.48e-01,   7.17e-01
#           > Iteration   2 - Residuals: 3.71e-03,   3.14e-03
#           > Iteration   3 - Residuals: 3.00e-16,   2.53e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 3.00e-16,   2.53e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  78 - Residuals: 6.95e-10,   1.66e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.02e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.54e-01,   7.39e-01
#           > Iteration   2 - Residuals: 7.18e-03,   7.04e-03
#           > Iteration   3 - Residuals: 2.69e-16,   2.64e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.69e-16,   2.64e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  79 - Residuals: 6.95e-10,   1.66e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.46e-01,   7.44e-01
#           > Iteration   2 - Residuals: 8.56e-03,   8.54e-03
#           > Iteration   3 - Residuals: 2.62e-16,   2.61e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.62e-16,   2.61e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  80 - Residuals: 6.87e-10,   1.64e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.07e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.29e-01,   6.83e-01
#           > Iteration   2 - Residuals: 7.68e-03,   7.20e-03
#           > Iteration   3 - Residuals: 2.78e-16,   2.60e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.78e-16,   2.60e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  81 - Residuals: 6.83e-10,   1.63e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.41e+00,   1.00e+00
#           > Iteration   1 - Residuals: 9.80e-01,   6.93e-01
#           > Iteration   2 - Residuals: 1.24e-02,   8.79e-03
#           > Iteration   3 - Residuals: 3.97e-16,   2.81e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 3.97e-16,   2.81e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  82 - Residuals: 6.83e-10,   1.63e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.37e-01,   7.36e-01
#           > Iteration   2 - Residuals: 5.53e-03,   5.53e-03
#           > Iteration   3 - Residuals: 2.89e-16,   2.89e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.89e-16,   2.89e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  83 - Residuals: 6.77e-10,   1.62e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.51e-01,   7.51e-01
#           > Iteration   2 - Residuals: 9.34e-03,   9.34e-03
#           > Iteration   3 - Residuals: 2.87e-16,   2.87e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.87e-16,   2.87e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  84 - Residuals: 6.71e-10,   1.60e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.41e+00,   1.00e+00
#           > Iteration   1 - Residuals: 1.07e+00,   7.60e-01
#           > Iteration   2 - Residuals: 1.03e-03,   7.26e-04
#           > Iteration   3 - Residuals: 4.94e-16,   3.49e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 4.94e-16,   3.49e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  85 - Residuals: 6.71e-10,   1.60e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.04e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.82e-01,   7.54e-01
#           > Iteration   2 - Residuals: 1.07e-02,   1.04e-02
#           > Iteration   3 - Residuals: 2.80e-16,   2.70e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.80e-16,   2.70e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  86 - Residuals: 6.63e-10,   1.58e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.58e-01,   7.58e-01
#           > Iteration   2 - Residuals: 9.70e-04,   9.69e-04
#           > Iteration   3 - Residuals: 2.92e-16,   2.92e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.92e-16,   2.92e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  87 - Residuals: 6.59e-10,   1.57e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.19e+00,   1.00e+00
#           > Iteration   1 - Residuals: 8.71e-01,   7.31e-01
# ...
#       > Iteration  88 - Residuals: 6.54e-10,   1.56e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.41e+00,   1.00e+00
#           > Iteration   1 - Residuals: 1.05e+00,   7.45e-01
#           > Iteration   2 - Residuals: 1.60e-02,   1.13e-02
#           > Iteration   3 - Residuals: 3.89e-16,   2.76e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 3.89e-16,   2.76e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  89 - Residuals: 6.46e-10,   1.54e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.26e+00,   1.00e+00
#           > Iteration   1 - Residuals: 9.43e-01,   7.51e-01
#           > Iteration   2 - Residuals: 9.39e-03,   7.48e-03
#           > Iteration   3 - Residuals: 3.98e-16,   3.17e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 3.98e-16,   3.17e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  90 - Residuals: 6.46e-10,   1.54e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.84e-01,   7.84e-01
#           > Iteration   2 - Residuals: 7.61e-04,   7.61e-04
#           > Iteration   3 - Residuals: 2.76e-16,   2.75e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.76e-16,   2.75e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  91 - Residuals: 6.38e-10,   1.52e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.03e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.78e-01,   7.56e-01
#           > Iteration   2 - Residuals: 4.96e-03,   4.82e-03
#           > Iteration   3 - Residuals: 3.30e-16,   3.21e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 3.30e-16,   3.21e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  92 - Residuals: 6.32e-10,   1.51e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.41e+00,   1.00e+00
#           > Iteration   1 - Residuals: 1.06e+00,   7.49e-01
#           > Iteration   2 - Residuals: 8.28e-03,   5.85e-03
#           > Iteration   3 - Residuals: 3.69e-16,   2.61e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 3.69e-16,   2.61e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  93 - Residuals: 6.32e-10,   1.51e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.47e-01,   7.47e-01
#           > Iteration   2 - Residuals: 3.46e-03,   3.46e-03
#           > Iteration   3 - Residuals: 2.63e-16,   2.63e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.63e-16,   2.63e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  94 - Residuals: 6.28e-10,   1.50e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.69e-01,   7.69e-01
#           > Iteration   2 - Residuals: 1.90e-04,   1.90e-04
#           > Iteration   3 - Residuals: 2.71e-16,   2.71e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.71e-16,   2.71e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  95 - Residuals: 6.21e-10,   1.49e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.41e+00,   1.00e+00
#           > Iteration   1 - Residuals: 1.12e+00,   7.94e-01
#           > Iteration   2 - Residuals: 1.04e-03,   7.37e-04
#           > Iteration   3 - Residuals: 4.17e-16,   2.95e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 4.17e-16,   2.95e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  96 - Residuals: 6.21e-10,   1.49e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.05e+00,   1.00e+00
#           > Iteration   1 - Residuals: 8.46e-01,   8.08e-01
#           > Iteration   2 - Residuals: 9.12e-04,   8.71e-04
#           > Iteration   3 - Residuals: 2.94e-16,   2.81e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.94e-16,   2.81e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  97 - Residuals: 6.09e-10,   1.46e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.00e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.60e-01,   7.59e-01
#           > Iteration   2 - Residuals: 1.27e-02,   1.27e-02
#           > Iteration   3 - Residuals: 2.74e-16,   2.74e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.74e-16,   2.74e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  98 - Residuals: 6.09e-10,   1.45e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.05e+00,   1.00e+00
#           > Iteration   1 - Residuals: 7.91e-01,   7.56e-01
#           > Iteration   2 - Residuals: 9.84e-03,   9.41e-03
#           > Iteration   3 - Residuals: 2.91e-16,   2.78e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.91e-16,   2.78e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration  99 - Residuals: 6.02e-10,   1.44e-03
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.26e+00,   1.00e+00
#           > Iteration   1 - Residuals: 9.35e-01,   7.42e-01
#           > Iteration   2 - Residuals: 1.31e-02,   1.04e-02
#           > Iteration   3 - Residuals: 3.90e-16,   3.10e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 3.90e-16,   3.10e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration 100 - Residuals: 5.96e-10,   1.42e-03
#     Solver FGMRES finished with reason SOLVER_DIVERGED_MAXITER
#     Iterations: 100 - Residuals: 5.96e-10,   1.42e-03
#     --------------- Exiting FGMRES solver -----------------
#   > Iteration   1 - Residuals: 1.12e-06,   2.68e+00
#     --------------- Starting FGMRES solver ----------------
#       > Iteration   0 - Residuals: 1.16e-06,   1.00e+00
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 9.51e-01,   1.00e+00
#           > Iteration   1 - Residuals: 7.05e-01,   7.42e-01
#           > Iteration   2 - Residuals: 9.98e-03,   1.05e-02
#           > Iteration   3 - Residuals: 3.62e-16,   3.81e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 3.62e-16,   3.81e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration   1 - Residuals: 6.69e-12,   5.76e-06
#     Solver FGMRES finished with reason SOLVER_CONVERGED_ATOL
#     Iterations:   1 - Residuals: 6.69e-12,   5.76e-06
#     --------------- Exiting FGMRES solver -----------------
#   > Iteration   2 - Residuals: 1.12e-06,   2.68e+00
#     --------------- Starting FGMRES solver ----------------
#       > Iteration   0 - Residuals: 7.71e-12,   1.00e+00
#     Solver FGMRES finished with reason SOLVER_CONVERGED_ATOL
#     Iterations:   0 - Residuals: 7.71e-12,   1.00e+00
#     --------------- Exiting FGMRES solver -----------------
#   > Iteration   3 - Residuals: 1.12e-06,   2.68e+00
#     --------------- Starting FGMRES solver ----------------
#       > Iteration   0 - Residuals: 1.02e-11,   1.00e+00
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 6.60e-01,   1.00e+00
#           > Iteration   1 - Residuals: 4.69e-01,   7.09e-01
#           > Iteration   2 - Residuals: 3.30e-03,   4.99e-03
#           > Iteration   3 - Residuals: 2.00e-16,   3.02e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 2.00e-16,   3.02e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration   1 - Residuals: 6.83e-12,   6.72e-01
#     Solver FGMRES finished with reason SOLVER_CONVERGED_ATOL
#     Iterations:   1 - Residuals: 6.83e-12,   6.72e-01
#     --------------- Exiting FGMRES solver -----------------
#   > Iteration   4 - Residuals: 1.12e-06,   2.68e+00
#     --------------- Starting FGMRES solver ----------------
#       > Iteration   0 - Residuals: 7.71e-12,   1.00e+00
#     Solver FGMRES finished with reason SOLVER_CONVERGED_ATOL
#     Iterations:   0 - Residuals: 7.71e-12,   1.00e+00
#     --------------- Exiting FGMRES solver -----------------
#   > Iteration   5 - Residuals: 1.12e-06,   2.68e+00
#     --------------- Starting FGMRES solver ----------------
#       > Iteration   0 - Residuals: 9.98e-12,   1.00e+00
#     Solver FGMRES finished with reason SOLVER_CONVERGED_ATOL
#     Iterations:   0 - Residuals: 9.98e-12,   1.00e+00
#     --------------- Exiting FGMRES solver -----------------
#   > Iteration   6 - Residuals: 1.12e-06,   2.68e+00
#     --------------- Starting FGMRES solver ----------------
#       > Iteration   0 - Residuals: 1.29e-11,   1.00e+00
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.35e-01,   1.00e+00
#           > Iteration   1 - Residuals: 9.49e-02,   7.04e-01
#           > Iteration   2 - Residuals: 8.87e-04,   6.58e-03
#           > Iteration   3 - Residuals: 4.88e-17,   3.62e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 4.88e-17,   3.62e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration   1 - Residuals: 6.68e-12,   5.17e-01
#     Solver FGMRES finished with reason SOLVER_CONVERGED_ATOL
#     Iterations:   1 - Residuals: 6.68e-12,   5.17e-01
#     --------------- Exiting FGMRES solver -----------------
#   > Iteration   7 - Residuals: 1.12e-06,   2.68e+00
#     --------------- Starting FGMRES solver ----------------
#       > Iteration   0 - Residuals: 1.00e-11,   1.00e+00
#         --------------- Starting CG solver --------------------
#           > Iteration   0 - Residuals: 1.47e-01,   1.00e+00
#           > Iteration   1 - Residuals: 1.03e-01,   7.03e-01
#           > Iteration   2 - Residuals: 1.07e-03,   7.28e-03
#           > Iteration   3 - Residuals: 3.90e-17,   2.66e-16
#         Solver CG finished with reason SOLVER_CONVERGED_RTOL
#         Iterations:   3 - Residuals: 3.90e-17,   2.66e-16
#         --------------- Exiting CG solver ---------------------
#       > Iteration   1 - Residuals: 6.79e-12,   6.79e-01
#     Solver FGMRES finished with reason SOLVER_CONVERGED_ATOL
#     Iterations:   1 - Residuals: 6.79e-12,   6.79e-01
#     --------------- Exiting FGMRES solver -----------------
#   > Iteration   8 - Residuals: 1.12e-06,   2.68e+00
#     --------------- Starting FGMRES solver ----------------
#       > Iteration   0 - Residuals: 6.80e-12,   1.00e+00
#     Solver FGMRES finished with reason SOLVER_CONVERGED_ATOL
#     Iterations:   0 - Residuals: 6.80e-12,   1.00e+00
#     --------------- Exiting FGMRES solver -----------------
#   > Iteration   9 - Residuals: 1.12e-06,   2.68e+00
#     --------------- Starting FGMRES solver ----------------
#       > Iteration   0 - Residuals: 6.81e-12,   1.00e+00
#     Solver FGMRES finished with reason SOLVER_CONVERGED_ATOL
#     Iterations:   0 - Residuals: 6.81e-12,   1.00e+00
#     --------------- Exiting FGMRES solver -----------------
#   > Iteration  10 - Residuals: 1.12e-06,   2.68e+00
#     --------------- Starting FGMRES solver ----------------
#       > Iteration   0 - Residuals: 6.81e-12,   1.00e+00
#     Solver FGMRES finished with reason SOLVER_CONVERGED_ATOL
#     Iterations:   0 - Residuals: 6.81e-12,   1.00e+00
#     --------------- Exiting FGMRES solver -----------------
#   > Iteration  11 - Residuals: 1.12e-06,   2.68e+00
#     --------------- Starting FGMRES solver ----------------
#       > Iteration   0 - Residuals: 6.82e-12,   1.00e+00
#     Solver FGMRES finished with reason SOLVER_CONVERGED_ATOL
#     Iterations:   0 - Residuals: 6.82e-12,   1.00e+00
#     --------------- Exiting FGMRES solver -----------------
#   > Iteration  12 - Residuals: 1.12e-06,   2.68e+00
#     --------------- Starting FGMRES solver ----------------
#       > Iteration   0 - Residuals: 6.83e-12,   1.00e+00
#     Solver FGMRES finished with reason SOLVER_CONVERGED_ATOL
#     Iterations:   0 - Residuals: 6.83e-12,   1.00e+00
#     --------------- Exiting FGMRES solver -----------------
#   > Iteration  13 - Residuals: 1.12e-06,   2.68e+00
#     --------------- Starting FGMRES solver ----------------
#       > Iteration   0 - Residuals: 6.84e-12,   1.00e+00
#     Solver FGMRES finished with reason SOLVER_CONVERGED_ATOL
#     Iterations:   0 - Residuals: 6.84e-12,   1.00e+00
#     --------------- Exiting FGMRES solver -----------------
#   > Iteration  14 - Residuals: 1.12e-06,   2.68e+00
#     --------------- Starting FGMRES solver ----------------
#       > Iteration   0 - Residuals: 6.84e-12,   1.00e+00
#     Solver FGMRES finished with reason SOLVER_CONVERGED_ATOL
#     Iterations:   0 - Residuals: 6.84e-12,   1.00e+00
#     --------------- Exiting FGMRES solver -----------------
#   > Iteration  15 - Residuals: 1.12e-06,   2.68e+00
#     --------------- Starting FGMRES solver ----------------
#       > Iteration   0 - Residuals: 6.85e-12,   1.00e+00
#     Solver FGMRES finished with reason SOLVER_CONVERGED_ATOL
#     Iterations:   0 - Residuals: 6.85e-12,   1.00e+00
#     --------------- Exiting FGMRES solver -----------------
#   > Iteration  16 - Residuals: 1.12e-06,   2.68e+00
#     --------------- Starting FGMRES solver ----------------
#       > Iteration   0 - Residuals: 6.86e-12,   1.00e+00
#     Solver FGMRES finished with reason SOLVER_CONVERGED_ATOL
#     Iterations:   0 - Residuals: 6.86e-12,   1.00e+00
#     --------------- Exiting FGMRES solver -----------------
#   > Iteration  17 - Residuals: 1.12e-06,   2.68e+00
#     --------------- Starting FGMRES solver ----------------
#       > Iteration   0 - Residuals: 6.87e-12,   1.00e+00
#     Solver FGMRES finished with reason SOLVER_CONVERGED_ATOL
#     Iterations:   0 - Residuals: 6.87e-12,   1.00e+00
#     --------------- Exiting FGMRES solver -----------------
#   > Iteration  18 - Residuals: 1.12e-06,   2.68e+00
#     --------------- Starting FGMRES solver ----------------
#       > Iteration   0 - Residuals: 6.87e-12,   1.00e+00
#     Solver FGMRES finished with reason SOLVER_CONVERGED_ATOL
#     Iterations:   0 - Residuals: 6.87e-12,   1.00e+00
#     --------------- Exiting FGMRES solver -----------------
#   > Iteration  19 - Residuals: 1.12e-06,   2.68e+00
#     --------------- Starting FGMRES solver ----------------
#       > Iteration   0 - Residuals: 6.88e-12,   1.00e+00
#     Solver FGMRES finished with reason SOLVER_CONVERGED_ATOL
#     Iterations:   0 - Residuals: 6.88e-12,   1.00e+00
#     --------------- Exiting FGMRES solver -----------------
#   > Iteration  20 - Residuals: 1.12e-06,   2.68e+00
# Solver Newton-Raphson finished with reason SOLVER_DIVERGED_MAXITER
# Iterations:  20 - Residuals: 1.12e-06,   2.68e+00
# --------------- Exiting Newton-Raphson solver ---------
# MultiFieldFEFunction():
#  num_fields: 2
#  num_cells: 706
#  DomainStyle: ReferenceDomain()
#  Triangulation: BodyFittedTriangulation()
#  Triangulation id: 4419575992183824025

# %% [markdown]
# Post-process and tidy up.

# %%
mag_integral = sqrt(sum( ∫( uh ⋅ uh )dΩ ))
domain_volume = sum(∫(1)dΩ)
avg_velocity_magnitude = mag_integral / domain_volume

println("Average |u| = ", avg_velocity_magnitude, " m/s. Domain volume = ", domain_volume, " m³.")

writevtk(Ω,"ArcticBoundaryCurrentModel7",cellfields=["uh"=>uh,"ph"=>ph])
# Out:
# Average |u| = 7.170257351874018e-6 m/s. Domain volume = 2.6434276685883336 m³.
# (["ArcticBoundaryCurrentModel7.vtu"],)
