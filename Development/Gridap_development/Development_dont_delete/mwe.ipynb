# %%
using GridapGmsh
# model = GmshDiscreteModel("demo_mwe.msh")
# model = GmshDiscreteModel("demo_testing_works_but_not_what_I_need.msh")
# model = GmshDiscreteModel("../testing/test2.msh")
# model = GmshDiscreteModel("cylinder_with_hole.msh")
model = GmshDiscreteModel("mwe_openCASCADE_works.msh")
model.face_labeling.tag_to_name
# Out:
# Info    : Reading 'mwe_openCASCADE_works.msh'...
# Info    : 12 entities
# Info    : 232 nodes
# Info    : 1122 elements
# Info    : Done reading 'mwe_openCASCADE_works.msh'
# 5-element Vector{String}:
#  "Patch1"
#  "Bottom"
#  "Patch2"
#  "Wall"
#  "Domain"
